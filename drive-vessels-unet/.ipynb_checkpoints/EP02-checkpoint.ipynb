# %%
import logging
import os
import sys
from glob import glob
import numpy as np

import torch
import torch.nn.functional as F
from dataloader import DRIVEDataset, Rescale, ToTensor, Normalize, WeightMap
from torch.utils.data import DataLoader
from torchvision import transforms
from torch.utils.tensorboard import SummaryWriter

import monai
from monai.visualize import plot_2d_or_3d_image

import matplotlib.pyplot as plt
      
from metrics import Metrics
# Out:
# 2024-10-06 23:19:24.608425: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-10-06 23:19:24.616839: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-06 23:19:24.626745: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-06 23:19:24.629638: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-10-06 23:19:24.637343: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-10-06 23:19:25.263046: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
monai.config.print_config()
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

IMAGE_ROOT = "./data_drive/traning/train"
LABEL_ROOT = "./data_drive/traning/train_masks"

# Obter listas de imagens e máscaras
image_files = glob(os.path.join(IMAGE_ROOT, "*_training.png"))
label_files = glob(os.path.join(LABEL_ROOT, "*_manual1.png"))

def get_id_from_filename(filename):
    return int(os.path.basename(filename).split("_")[0])


# Criar um dicionário para mapear IDs para arquivos
image_dict = {get_id_from_filename(f): f for f in image_files}
label_dict = {get_id_from_filename(f): f for f in label_files}

# Criar pares de imagem-máscara com base nos IDs
image_label_pairs = [(image_dict[id], label_dict[id]) for id in image_dict if id in label_dict]

# Dividir em conjuntos de treinamento e validação
train_size = int(0.8 * len(image_label_pairs))
train_files = image_label_pairs[:train_size]
val_files = image_label_pairs[train_size:]

train_transform = transforms.Compose([
    Rescale((512, 512)),
    Normalize(),
    WeightMap(),
    ToTensor(),
])

valid_transform = transforms.Compose([
    Rescale((512, 512)),
    Normalize(),
    WeightMap(),
    ToTensor(),
])


# Desempacotar as tuplas em listas separadas
train_images, train_labels = zip(*train_files)
val_images, val_labels = zip(*val_files)

# Criar os datasets
train_ds = DRIVEDataset(train_images, train_labels, transform=train_transform)
valid_ds = DRIVEDataset(val_images, val_labels, transform=valid_transform)
# Out:
# MONAI version: 1.3.2
# Numpy version: 1.26.4
# Pytorch version: 2.4.1+cu121
# MONAI flags: HAS_EXT = False, USE_COMPILED = False, USE_META_DICT = False
# MONAI rev id: 59a7211070538586369afd4a01eca0a7fe2e742e
# MONAI __file__: /home/<username>/anaconda3/lib/python3.12/site-packages/monai/__init__.py
#
# Optional dependencies:
# Pytorch Ignite version: NOT INSTALLED or UNKNOWN VERSION.
# ITK version: NOT INSTALLED or UNKNOWN VERSION.
# Nibabel version: NOT INSTALLED or UNKNOWN VERSION.
# scikit-image version: 0.24.0
# scipy version: 1.14.1
# Pillow version: 10.4.0
# Tensorboard version: 2.17.1
# gdown version: NOT INSTALLED or UNKNOWN VERSION.
# TorchVision version: 0.19.1+cu121
# tqdm version: 4.66.5
# lmdb version: 1.4.1
# psutil version: 5.9.0
# pandas version: 2.2.2
# einops version: 0.8.0
# transformers version: NOT INSTALLED or UNKNOWN VERSION.
# mlflow version: NOT INSTALLED or UNKNOWN VERSION.
# pynrrd version: NOT INSTALLED or UNKNOWN VERSION.
# clearml version: NOT INSTALLED or UNKNOWN VERSION.
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
print("Imagens de treinamento:")
print(train_images)

print("\nMáscaras de treinamento:")
print(train_labels)

print("\nImagens de validação:")
print(val_images)

print("\nMáscaras de validação:")
print(val_labels)
# Imprime os índices
print("Índices de Treinamento:", train_images)
print("Índices de Validação:", train_labels)
# Out:
# Imagens de treinamento:
# ('./data_drive/traning/train/31_training.png', './data_drive/traning/train/33_training.png', './data_drive/traning/train/28_training.png', './data_drive/traning/train/37_training.png', './data_drive/traning/train/21_training.png', './data_drive/traning/train/39_training.png', './data_drive/traning/train/30_training.png', './data_drive/traning/train/24_training.png', './data_drive/traning/train/27_training.png', './data_drive/traning/train/36_training.png', './data_drive/traning/train/26_training.png', './data_drive/traning/train/25_training.png', './data_drive/traning/train/38_training.png', './data_drive/traning/train/34_training.png', './data_drive/traning/train/32_training.png', './data_drive/traning/train/35_training.png')
#
# Máscaras de treinamento:
# ('./data_drive/traning/train_masks/31_manual1.png', './data_drive/traning/train_masks/33_manual1.png', './data_drive/traning/train_masks/28_manual1.png', './data_drive/traning/train_masks/37_manual1.png', './data_drive/traning/train_masks/21_manual1.png', './data_drive/traning/train_masks/39_manual1.png', './data_drive/traning/train_masks/30_manual1.png', './data_drive/traning/train_masks/24_manual1.png', './data_drive/traning/train_masks/27_manual1.png', './data_drive/traning/train_masks/36_manual1.png', './data_drive/traning/train_masks/26_manual1.png', './data_drive/traning/train_masks/25_manual1.png', './data_drive/traning/train_masks/38_manual1.png', './data_drive/traning/train_masks/34_manual1.png', './data_drive/traning/train_masks/32_manual1.png', './data_drive/traning/train_masks/35_manual1.png')
#
# Imagens de validação:
# ('./data_drive/traning/train/40_training.png', './data_drive/traning/train/22_training.png', './data_drive/traning/train/29_training.png', './data_drive/traning/train/23_training.png')
#
# Máscaras de validação:
# ('./data_drive/traning/train_masks/40_manual1.png', './data_drive/traning/train_masks/22_manual1.png', './data_drive/traning/train_masks/29_manual1.png', './data_drive/traning/train_masks/23_manual1.png')
# Índices de Treinamento: ('./data_drive/traning/train/31_training.png', './data_drive/traning/train/33_training.png', './data_drive/traning/train/28_training.png', './data_drive/traning/train/37_training.png', './data_drive/traning/train/21_training.png', './data_drive/traning/train/39_training.png', './data_drive/traning/train/30_training.png', './data_drive/traning/train/24_training.png', './data_drive/traning/train/27_training.png', './data_drive/traning/train/36_training.png', './data_drive/traning/train/26_training.png', './data_drive/traning/train/25_training.png', './data_drive/traning/train/38_training.png', './data_drive/traning/train/34_training.png', './data_drive/traning/train/32_training.png', './data_drive/traning/train/35_training.png')
# Índices de Validação: ('./data_drive/traning/train_masks/31_manual1.png', './data_drive/traning/train_masks/33_manual1.png', './data_drive/traning/train_masks/28_manual1.png', './data_drive/traning/train_masks/37_manual1.png', './data_drive/traning/train_masks/21_manual1.png', './data_drive/traning/train_masks/39_manual1.png', './data_drive/traning/train_masks/30_manual1.png', './data_drive/traning/train_masks/24_manual1.png', './data_drive/traning/train_masks/27_manual1.png', './data_drive/traning/train_masks/36_manual1.png', './data_drive/traning/train_masks/26_manual1.png', './data_drive/traning/train_masks/25_manual1.png', './data_drive/traning/train_masks/38_manual1.png', './data_drive/traning/train_masks/34_manual1.png', './data_drive/traning/train_masks/32_manual1.png', './data_drive/traning/train_masks/35_manual1.png')

# %%
print("Tamanho do Dataset de Treinamento:", len(train_ds))
# Out:
# Tamanho do Dataset de Treinamento: 16

# %% [markdown]
# Test data set

# %%
sample = DRIVEDataset(train_images[:1], train_labels[:1], transform=train_transform)[0]  # Use train_images e train_labels
print("Shape of transformed image:", sample['img'].shape)
print("Shape of transformed label:", sample['seg'].shape)
# Out:
# Shape of transformed image: torch.Size([3, 512, 512])
# Shape of transformed label: torch.Size([512, 512])

# %% [markdown]
# Shape of transformed image: torch.Size([3, 512, 512])
# Shape of transformed label: torch.Size([512, 512])
# Shape of transformed weight map: torch.Size([512, 512])

# %%
train_loader = DataLoader(
    train_ds, batch_size=4, shuffle=True, num_workers=0, pin_memory=True,
)

val_loader = DataLoader(
    valid_ds, batch_size=2, shuffle=True, num_workers=0, pin_memory=True,
)

# %%
# Test the data loaders
for batch_idx, batch_data in enumerate(train_loader):
    print(f"Train Batch {batch_idx+1}:")
    print("  Image Shape:", batch_data['img'].shape)
    print("  Label Shape:", batch_data['seg'].shape)
    print("  Weight Map Shape:", batch_data['map'].shape)

for batch_idx, batch_data in enumerate(val_loader):
    print(f"Validation Batch {batch_idx+1}:")
    print("  Image Shape:", batch_data['img'].shape)
    print("  Label Shape:", batch_data['seg'].shape)
    print("  Weight Map Shape:", batch_data['map'].shape)
    break  # Just display one batch from the validation loader
# Out:
# Train Batch 1:
#   Image Shape: torch.Size([4, 3, 512, 512])
#   Label Shape: torch.Size([4, 512, 512])
#   Weight Map Shape: torch.Size([4, 512, 512])
# Train Batch 2:
#   Image Shape: torch.Size([4, 3, 512, 512])
#   Label Shape: torch.Size([4, 512, 512])
#   Weight Map Shape: torch.Size([4, 512, 512])
# Train Batch 3:
#   Image Shape: torch.Size([4, 3, 512, 512])
#   Label Shape: torch.Size([4, 512, 512])
#   Weight Map Shape: torch.Size([4, 512, 512])
# Train Batch 4:
#   Image Shape: torch.Size([4, 3, 512, 512])
#   Label Shape: torch.Size([4, 512, 512])
#   Weight Map Shape: torch.Size([4, 512, 512])
# Validation Batch 1:
#   Image Shape: torch.Size([2, 3, 512, 512])
#   Label Shape: torch.Size([2, 512, 512])
#   Weight Map Shape: torch.Size([2, 512, 512])

# %% [markdown]
# Train Batch 1:
#   Image Shape: torch.Size([4, 3, 512, 512])
#   Label Shape: torch.Size([4, 512, 512])
#   Weight Map Shape: torch.Size([4, 512, 512])
# Train Batch 2:
#   Image Shape: torch.Size([4, 3, 512, 512])
#   Label Shape: torch.Size([4, 512, 512])
#   Weight Map Shape: torch.Size([4, 512, 512])
# Train Batch 3:
#   Image Shape: torch.Size([2, 3, 512, 512])
#   Label Shape: torch.Size([2, 512, 512])
#   Weight Map Shape: torch.Size([2, 512, 512])
# Validation Batch 1:
#   Image Shape: torch.Size([2, 3, 512, 512])
#   Label Shape: torch.Size([2, 512, 512])
#   Weight Map Shape: torch.Size([2, 512, 512])

# %%
# create UNet and Adam optimizer
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = monai.networks.nets.UNet(
    spatial_dims=2,
    in_channels=3,
    out_channels=1,
    channels=(16, 32, 64, 128, 256),
    strides=(2, 2, 2, 2),
    num_res_units=2,
).to(device)
loss_function = F.binary_cross_entropy_with_logits
optimizer = torch.optim.Adam(model.parameters(), lr=5e-5, weight_decay=5e-5)

# start a typical PyTorch training
epochs_total = 1000
val_interval = 1
best_loss = np.inf
best_metric_epoch = -1
epoch_loss_values = list()
metric_values = list()
writer = SummaryWriter()
      
metrics = Metrics()

# %%
for epoch in range(epochs_total):
    print("-" * 10)
    print(f"epoch {epoch + 1}/{epochs_total}")
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels, weights = (
            batch_data["img"].to(device),
            batch_data["seg"].to(device),
            batch_data["map"].to(device),
        )
        optimizer.zero_grad()
        outputs = model(inputs).squeeze()
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        epoch_len = len(train_ds) // train_loader.batch_size
        print(f"{step}/{epoch_len}, train_loss: {loss.item():.4f}")
        writer.add_scalar("train_loss", loss.item(), epoch_len * epoch + step)
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print(f"epoch {epoch + 1} average loss: {epoch_loss:.4f}")

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            epoch_val_loss = []
            epoch_val_dice = []  # Define epoch_val_dice here
            epoch_val_precision = []
            epoch_val_recall = []  # Define epoch_val_recall aqui
            epoch_val_f1 =[]
            epoch_val_iou= [] 
            val_images = None
            val_labels = None
            val_outputs = None
            for val_data in val_loader:
                val_images, val_labels, val_weights = (
                    val_data["img"].to(device),
                    val_data["seg"].to(device),
                    val_data["map"].to(device),
                )
                  
                # ... dentro do loop de validação ...

                val_outputs = model(val_images).squeeze()
                loss = loss_function(val_outputs, val_labels)
                epoch_val_loss.append(loss.item())
                
                # Calcule a pontuação Dice, precisão e revocação para cada imagem no lote
                dice_scores = []
                precision_scores = []
                recall_scores = []
                f1_scores = []
                iou_scores = []  # Lista para armazenar as pontuações IoU
                for i in range(val_outputs.shape[0]):
                    dice_score = metrics.calculate_dice_score(val_outputs[i], val_labels[i])
                    dice_scores.append(dice_score.cpu().item())

                    precision = metrics.calculate_precision(val_outputs[i], val_labels[i])
                    precision_scores.append(precision.cpu().item())

                    recall = metrics.calculate_recall(val_outputs[i], val_labels[i])
                    recall_scores.append(recall.cpu().item())

                    f1_score = metrics.calculate_f1_score(precision, recall)
                    f1_scores.append(f1_score.cpu().item())

                    iou_score = metrics.calculate_iou(val_outputs[i], val_labels[i])  # Calcule o IoU
                    iou_scores.append(iou_score.cpu().item())  # Adicione à lista de pontuações IoU

            # Calcule a média das pontuações Dice, precisão, revocação e F1-Score do lote após o loop
            epoch_val_dice.append(np.mean(dice_scores))
            epoch_val_precision.append(np.mean(precision_scores))
            epoch_val_recall.append(np.mean(recall_scores))
            epoch_val_f1.append(np.mean(f1_scores))
            epoch_val_iou.append(np.mean(iou_scores))  # Calcule a média das pontuações IoU
                
           # Calcule a média das pontuações da época
            epoch_val_loss = np.mean(epoch_val_loss)  # Calcule a média da perda de validação da época
            epoch_val_dice = np.mean(epoch_val_dice)  # Calcule a média da pontuação Dice da época
            epoch_val_precision = np.mean(epoch_val_precision)  # Calcule a média da precisão da época
            epoch_val_recall = np.mean(epoch_val_recall)  # Calcule a média da revocação da época
            epoch_val_f1 = np.mean(epoch_val_f1)  # Calcule a média do F1-Score da época
            epoch_val_iou = np.mean(epoch_val_iou)  # Calcule a média do IoU da época

            # Imprima a pontuação Dice e precisão médias da época
            print(f"Epoch {epoch + 1} - Dice Score: {epoch_val_dice:.4f}, Precision: {epoch_val_precision:.4f}, Recall: {epoch_val_recall:.4f}, F1-Score: {epoch_val_f1:.4f}, IoU: {epoch_val_iou:.4f}")

            # Agora compare a média de epoch_val_loss com best_loss
            if epoch_val_loss < best_loss:
                best_loss = epoch_val_loss
                best_metric_epoch = epoch + 1
                torch.save(
                    model.state_dict(), "best_metric_model_segmentation2d_dict.pth"
                )
                print("saved new best metric model")
            print(
                "current epoch: {} current val loss: {:.4f} best val loss: {:.4f} at epoch {}".format(
                    epoch + 1, epoch_val_loss, best_loss, best_metric_epoch
                )
            )
            
            writer.add_scalar("val_loss", epoch_val_loss, epoch + 1)
            # plot the last model output as GIF image in TensorBoard with the corresponding image and label
            plot_2d_or_3d_image(val_images, epoch + 1, writer, index=0, tag="image")
            plot_2d_or_3d_image(val_labels, epoch + 1, writer, index=0, tag="label")
            plot_2d_or_3d_image(
                val_outputs, epoch + 1, writer, index=0, tag="output"
            )

            # Plota a imagem, máscara e resultado usando matplotlib
            # plt.figure(figsize=(15, 5))
            # plt.subplot(1, 3, 1)
            # plt.imshow(val_images[0].cpu().numpy().transpose(1, 2, 0))
            # plt.title("Imagem Original")
            # plt.subplot(1, 3, 2)
            # plt.imshow(val_labels[0].cpu().numpy(), cmap="gray")
            # plt.title("Máscara")
            # plt.subplot(1, 3, 3)
            # plt.imshow(torch.sigmoid(val_outputs[0]).cpu().numpy() > 0.5, cmap="gray")
            # plt.title("Resultado da Segmentação")
            # plt.show()



print(f"train completed, best_loss: {best_loss:.4f} at epoch: {best_metric_epoch}")
writer.close()
# Out:
# ----------
# epoch 1/1000
# 1/4, train_loss: 0.7368
# 2/4, train_loss: 0.7376
# 3/4, train_loss: 0.7330
# 4/4, train_loss: 0.7285
# epoch 1 average loss: 0.7340
# Epoch 1 - Dice Score: 0.0030, Precision: 0.0016, Recall: 0.1396, F1-Score: 0.0031, IoU: 0.0014
# saved new best metric model
# current epoch: 1 current val loss: 0.7249 best val loss: 0.7249 at epoch 1
# ----------
# epoch 2/1000
# 1/4, train_loss: 0.7272
# 2/4, train_loss: 0.7225
# 3/4, train_loss: 0.7210
# 4/4, train_loss: 0.7181
# epoch 2 average loss: 0.7222
# Epoch 2 - Dice Score: -0.0359, Precision: -0.0116, Recall: 0.1090, F1-Score: -0.0392, IoU: -0.0157
# saved new best metric model
# current epoch: 2 current val loss: 0.7147 best val loss: 0.7147 at epoch 2
# ----------
# epoch 3/1000
# 1/4, train_loss: 0.7136
# 2/4, train_loss: 0.7147
# 3/4, train_loss: 0.7112
# 4/4, train_loss: 0.7116
# epoch 3 average loss: 0.7128
# Epoch 3 - Dice Score: 0.0216, Precision: 0.0145, Recall: 0.0768, F1-Score: 0.0223, IoU: 0.0107
# saved new best metric model
# current epoch: 3 current val loss: 0.7063 best val loss: 0.7063 at epoch 3
# ----------
# epoch 4/1000
# 1/4, train_loss: 0.7087
# 2/4, train_loss: 0.7058
# 3/4, train_loss: 0.7055
# 4/4, train_loss: 0.7004
# epoch 4 average loss: 0.7051
# Epoch 4 - Dice Score: -0.0004, Precision: -0.0003, Recall: 0.0245, F1-Score: -0.0006, IoU: -0.0001
# saved new best metric model
# current epoch: 4 current val loss: 0.6994 best val loss: 0.6994 at epoch 4
# ----------
# epoch 5/1000
# 1/4, train_loss: 0.7001
# 2/4, train_loss: 0.6988
# 3/4, train_loss: 0.6970
# 4/4, train_loss: 0.6977
# epoch 5 average loss: 0.6984
# Epoch 5 - Dice Score: 0.0001, Precision: -0.0000, Recall: 0.0021, F1-Score: -0.0000, IoU: 0.0001
# saved new best metric model
# current epoch: 5 current val loss: 0.6933 best val loss: 0.6933 at epoch 5
# ----------
# epoch 6/1000
# 1/4, train_loss: 0.6952
# 2/4, train_loss: 0.6919
# 3/4, train_loss: 0.6933
# 4/4, train_loss: 0.6891
# epoch 6 average loss: 0.6924
# Epoch 6 - Dice Score: -0.0003, Precision: -0.0002, Recall: 0.0173, F1-Score: -0.0004, IoU: -0.0001
# saved new best metric model
# current epoch: 6 current val loss: 0.6877 best val loss: 0.6877 at epoch 6
# ----------
# epoch 7/1000
# 1/4, train_loss: 0.6880
# 2/4, train_loss: 0.6873
# 3/4, train_loss: 0.6893
# 4/4, train_loss: 0.6820
# epoch 7 average loss: 0.6867
# Epoch 7 - Dice Score: 0.0001, Precision: -0.0000, Recall: -0.0015, F1-Score: -0.0000, IoU: 0.0001
# saved new best metric model
# current epoch: 7 current val loss: 0.6823 best val loss: 0.6823 at epoch 7
# ----------
# epoch 8/1000
# 1/4, train_loss: 0.6836
# 2/4, train_loss: 0.6823
# 3/4, train_loss: 0.6805
# 4/4, train_loss: 0.6785
# epoch 8 average loss: 0.6812
# Epoch 8 - Dice Score: 0.0004, Precision: 0.0002, Recall: -0.0367, F1-Score: 0.0004, IoU: 0.0002
# saved new best metric model
# current epoch: 8 current val loss: 0.6771 best val loss: 0.6771 at epoch 8
# ----------
# epoch 9/1000
# 1/4, train_loss: 0.6775
# 2/4, train_loss: 0.6774
# 3/4, train_loss: 0.6751
# 4/4, train_loss: 0.6737
# epoch 9 average loss: 0.6759
# Epoch 9 - Dice Score: 0.0004, Precision: 0.0002, Recall: -0.0379, F1-Score: 0.0004, IoU: 0.0002
# saved new best metric model
# current epoch: 9 current val loss: 0.6722 best val loss: 0.6722 at epoch 9
# ----------
# epoch 10/1000
# 1/4, train_loss: 0.6715
# 2/4, train_loss: 0.6718
# 3/4, train_loss: 0.6721
# 4/4, train_loss: 0.6682
# epoch 10 average loss: 0.6709
# Epoch 10 - Dice Score: 0.0005, Precision: 0.0002, Recall: -0.0628, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 10 current val loss: 0.6675 best val loss: 0.6675 at epoch 10
# ----------
# epoch 11/1000
# 1/4, train_loss: 0.6684
# 2/4, train_loss: 0.6666
# 3/4, train_loss: 0.6651
# 4/4, train_loss: 0.6646
# epoch 11 average loss: 0.6662
# Epoch 11 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.0607, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 11 current val loss: 0.6632 best val loss: 0.6632 at epoch 11
# ----------
# epoch 12/1000
# 1/4, train_loss: 0.6642
# 2/4, train_loss: 0.6613
# 3/4, train_loss: 0.6607
# 4/4, train_loss: 0.6608
# epoch 12 average loss: 0.6617
# Epoch 12 - Dice Score: 0.0005, Precision: 0.0002, Recall: -0.0674, F1-Score: 0.0004, IoU: 0.0003
# saved new best metric model
# current epoch: 12 current val loss: 0.6592 best val loss: 0.6592 at epoch 12
# ----------
# epoch 13/1000
# 1/4, train_loss: 0.6584
# 2/4, train_loss: 0.6578
# 3/4, train_loss: 0.6582
# 4/4, train_loss: 0.6562
# epoch 13 average loss: 0.6577
# Epoch 13 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.0944, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 13 current val loss: 0.6555 best val loss: 0.6555 at epoch 13
# ----------
# epoch 14/1000
# 1/4, train_loss: 0.6553
# 2/4, train_loss: 0.6530
# 3/4, train_loss: 0.6538
# 4/4, train_loss: 0.6532
# epoch 14 average loss: 0.6538
# Epoch 14 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.0915, F1-Score: 0.0006, IoU: 0.0004
# saved new best metric model
# current epoch: 14 current val loss: 0.6521 best val loss: 0.6521 at epoch 14
# ----------
# epoch 15/1000
# 1/4, train_loss: 0.6506
# 2/4, train_loss: 0.6504
# 3/4, train_loss: 0.6505
# 4/4, train_loss: 0.6498
# epoch 15 average loss: 0.6503
# Epoch 15 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.0963, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 15 current val loss: 0.6490 best val loss: 0.6490 at epoch 15
# ----------
# epoch 16/1000
# 1/4, train_loss: 0.6480
# 2/4, train_loss: 0.6473
# 3/4, train_loss: 0.6466
# 4/4, train_loss: 0.6464
# epoch 16 average loss: 0.6471
# Epoch 16 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1069, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 16 current val loss: 0.6462 best val loss: 0.6462 at epoch 16
# ----------
# epoch 17/1000
# 1/4, train_loss: 0.6450
# 2/4, train_loss: 0.6443
# 3/4, train_loss: 0.6446
# 4/4, train_loss: 0.6425
# epoch 17 average loss: 0.6441
# Epoch 17 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1104, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 17 current val loss: 0.6435 best val loss: 0.6435 at epoch 17
# ----------
# epoch 18/1000
# 1/4, train_loss: 0.6427
# 2/4, train_loss: 0.6419
# 3/4, train_loss: 0.6414
# 4/4, train_loss: 0.6396
# epoch 18 average loss: 0.6414
# Epoch 18 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1183, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 18 current val loss: 0.6410 best val loss: 0.6410 at epoch 18
# ----------
# epoch 19/1000
# 1/4, train_loss: 0.6408
# 2/4, train_loss: 0.6392
# 3/4, train_loss: 0.6383
# 4/4, train_loss: 0.6372
# epoch 19 average loss: 0.6389
# Epoch 19 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1233, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 19 current val loss: 0.6386 best val loss: 0.6386 at epoch 19
# ----------
# epoch 20/1000
# 1/4, train_loss: 0.6369
# 2/4, train_loss: 0.6365
# 3/4, train_loss: 0.6372
# 4/4, train_loss: 0.6357
# epoch 20 average loss: 0.6366
# Epoch 20 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1276, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 20 current val loss: 0.6364 best val loss: 0.6364 at epoch 20
# ----------
# epoch 21/1000
# 1/4, train_loss: 0.6348
# 2/4, train_loss: 0.6341
# 3/4, train_loss: 0.6344
# 4/4, train_loss: 0.6345
# epoch 21 average loss: 0.6344
# Epoch 21 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1386, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 21 current val loss: 0.6343 best val loss: 0.6343 at epoch 21
# ----------
# epoch 22/1000
# 1/4, train_loss: 0.6334
# 2/4, train_loss: 0.6331
# 3/4, train_loss: 0.6314
# 4/4, train_loss: 0.6322
# epoch 22 average loss: 0.6325
# Epoch 22 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1351, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 22 current val loss: 0.6323 best val loss: 0.6323 at epoch 22
# ----------
# epoch 23/1000
# 1/4, train_loss: 0.6307
# 2/4, train_loss: 0.6310
# 3/4, train_loss: 0.6309
# 4/4, train_loss: 0.6302
# epoch 23 average loss: 0.6307
# Epoch 23 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1391, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 23 current val loss: 0.6306 best val loss: 0.6306 at epoch 23
# ----------
# epoch 24/1000
# 1/4, train_loss: 0.6296
# 2/4, train_loss: 0.6296
# 3/4, train_loss: 0.6296
# 4/4, train_loss: 0.6276
# epoch 24 average loss: 0.6291
# Epoch 24 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1475, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 24 current val loss: 0.6289 best val loss: 0.6289 at epoch 24
# ----------
# epoch 25/1000
# 1/4, train_loss: 0.6281
# 2/4, train_loss: 0.6276
# 3/4, train_loss: 0.6276
# 4/4, train_loss: 0.6270
# epoch 25 average loss: 0.6276
# Epoch 25 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1492, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 25 current val loss: 0.6273 best val loss: 0.6273 at epoch 25
# ----------
# epoch 26/1000
# 1/4, train_loss: 0.6270
# 2/4, train_loss: 0.6269
# 3/4, train_loss: 0.6254
# 4/4, train_loss: 0.6252
# epoch 26 average loss: 0.6262
# Epoch 26 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1477, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 26 current val loss: 0.6259 best val loss: 0.6259 at epoch 26
# ----------
# epoch 27/1000
# 1/4, train_loss: 0.6242
# 2/4, train_loss: 0.6259
# 3/4, train_loss: 0.6244
# 4/4, train_loss: 0.6248
# epoch 27 average loss: 0.6248
# Epoch 27 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1540, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 27 current val loss: 0.6246 best val loss: 0.6246 at epoch 27
# ----------
# epoch 28/1000
# 1/4, train_loss: 0.6240
# 2/4, train_loss: 0.6244
# 3/4, train_loss: 0.6229
# 4/4, train_loss: 0.6229
# epoch 28 average loss: 0.6236
# Epoch 28 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1561, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 28 current val loss: 0.6232 best val loss: 0.6232 at epoch 28
# ----------
# epoch 29/1000
# 1/4, train_loss: 0.6228
# 2/4, train_loss: 0.6217
# 3/4, train_loss: 0.6221
# 4/4, train_loss: 0.6228
# epoch 29 average loss: 0.6224
# Epoch 29 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1579, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 29 current val loss: 0.6221 best val loss: 0.6221 at epoch 29
# ----------
# epoch 30/1000
# 1/4, train_loss: 0.6207
# 2/4, train_loss: 0.6213
# 3/4, train_loss: 0.6215
# 4/4, train_loss: 0.6214
# epoch 30 average loss: 0.6212
# Epoch 30 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1562, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 30 current val loss: 0.6209 best val loss: 0.6209 at epoch 30
# ----------
# epoch 31/1000
# 1/4, train_loss: 0.6201
# 2/4, train_loss: 0.6215
# 3/4, train_loss: 0.6200
# 4/4, train_loss: 0.6189
# epoch 31 average loss: 0.6201
# Epoch 31 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1579, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 31 current val loss: 0.6198 best val loss: 0.6198 at epoch 31
# ----------
# epoch 32/1000
# 1/4, train_loss: 0.6203
# 2/4, train_loss: 0.6190
# 3/4, train_loss: 0.6189
# 4/4, train_loss: 0.6180
# epoch 32 average loss: 0.6190
# Epoch 32 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1616, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 32 current val loss: 0.6189 best val loss: 0.6189 at epoch 32
# ----------
# epoch 33/1000
# 1/4, train_loss: 0.6188
# 2/4, train_loss: 0.6184
# 3/4, train_loss: 0.6180
# 4/4, train_loss: 0.6170
# epoch 33 average loss: 0.6180
# Epoch 33 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1595, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 33 current val loss: 0.6179 best val loss: 0.6179 at epoch 33
# ----------
# epoch 34/1000
# 1/4, train_loss: 0.6177
# 2/4, train_loss: 0.6168
# 3/4, train_loss: 0.6171
# 4/4, train_loss: 0.6167
# epoch 34 average loss: 0.6171
# Epoch 34 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1646, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 34 current val loss: 0.6168 best val loss: 0.6168 at epoch 34
# ----------
# epoch 35/1000
# 1/4, train_loss: 0.6172
# 2/4, train_loss: 0.6157
# 3/4, train_loss: 0.6161
# 4/4, train_loss: 0.6154
# epoch 35 average loss: 0.6161
# Epoch 35 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1635, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 35 current val loss: 0.6159 best val loss: 0.6159 at epoch 35
# ----------
# epoch 36/1000
# 1/4, train_loss: 0.6155
# 2/4, train_loss: 0.6145
# 3/4, train_loss: 0.6152
# 4/4, train_loss: 0.6156
# epoch 36 average loss: 0.6152
# Epoch 36 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1653, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 36 current val loss: 0.6148 best val loss: 0.6148 at epoch 36
# ----------
# epoch 37/1000
# 1/4, train_loss: 0.6148
# 2/4, train_loss: 0.6143
# 3/4, train_loss: 0.6147
# 4/4, train_loss: 0.6134
# epoch 37 average loss: 0.6143
# Epoch 37 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1650, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 37 current val loss: 0.6140 best val loss: 0.6140 at epoch 37
# ----------
# epoch 38/1000
# 1/4, train_loss: 0.6125
# 2/4, train_loss: 0.6147
# 3/4, train_loss: 0.6131
# 4/4, train_loss: 0.6133
# epoch 38 average loss: 0.6134
# Epoch 38 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1655, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 38 current val loss: 0.6133 best val loss: 0.6133 at epoch 38
# ----------
# epoch 39/1000
# 1/4, train_loss: 0.6128
# 2/4, train_loss: 0.6119
# 3/4, train_loss: 0.6129
# 4/4, train_loss: 0.6125
# epoch 39 average loss: 0.6125
# Epoch 39 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1677, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 39 current val loss: 0.6123 best val loss: 0.6123 at epoch 39
# ----------
# epoch 40/1000
# 1/4, train_loss: 0.6114
# 2/4, train_loss: 0.6118
# 3/4, train_loss: 0.6126
# 4/4, train_loss: 0.6111
# epoch 40 average loss: 0.6117
# Epoch 40 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1683, F1-Score: 0.0007, IoU: 0.0004
# saved new best metric model
# current epoch: 40 current val loss: 0.6115 best val loss: 0.6115 at epoch 40
# ----------
# epoch 41/1000
# 1/4, train_loss: 0.6124
# 2/4, train_loss: 0.6108
# 3/4, train_loss: 0.6105
# 4/4, train_loss: 0.6099
# epoch 41 average loss: 0.6109
# Epoch 41 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1672, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 41 current val loss: 0.6110 best val loss: 0.6110 at epoch 41
# ----------
# epoch 42/1000
# 1/4, train_loss: 0.6106
# 2/4, train_loss: 0.6100
# 3/4, train_loss: 0.6099
# 4/4, train_loss: 0.6102
# epoch 42 average loss: 0.6102
# Epoch 42 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1684, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 42 current val loss: 0.6100 best val loss: 0.6100 at epoch 42
# ----------
# epoch 43/1000
# 1/4, train_loss: 0.6102
# 2/4, train_loss: 0.6098
# 3/4, train_loss: 0.6092
# 4/4, train_loss: 0.6084
# epoch 43 average loss: 0.6094
# Epoch 43 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1693, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 43 current val loss: 0.6092 best val loss: 0.6092 at epoch 43
# ----------
# epoch 44/1000
# 1/4, train_loss: 0.6088
# 2/4, train_loss: 0.6089
# 3/4, train_loss: 0.6084
# 4/4, train_loss: 0.6086
# epoch 44 average loss: 0.6087
# Epoch 44 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1699, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 44 current val loss: 0.6090 best val loss: 0.6090 at epoch 44
# ----------
# epoch 45/1000
# 1/4, train_loss: 0.6077
# 2/4, train_loss: 0.6089
# 3/4, train_loss: 0.6080
# 4/4, train_loss: 0.6078
# epoch 45 average loss: 0.6081
# Epoch 45 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1703, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 45 current val loss: 0.6081 best val loss: 0.6081 at epoch 45
# ----------
# epoch 46/1000
# 1/4, train_loss: 0.6081
# 2/4, train_loss: 0.6071
# 3/4, train_loss: 0.6077
# 4/4, train_loss: 0.6067
# epoch 46 average loss: 0.6074
# Epoch 46 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1689, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 46 current val loss: 0.6074 best val loss: 0.6074 at epoch 46
# ----------
# epoch 47/1000
# 1/4, train_loss: 0.6082
# 2/4, train_loss: 0.6065
# 3/4, train_loss: 0.6066
# 4/4, train_loss: 0.6059
# epoch 47 average loss: 0.6068
# Epoch 47 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1698, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 47 current val loss: 0.6066 best val loss: 0.6066 at epoch 47
# ----------
# epoch 48/1000
# 1/4, train_loss: 0.6060
# 2/4, train_loss: 0.6057
# 3/4, train_loss: 0.6062
# 4/4, train_loss: 0.6066
# epoch 48 average loss: 0.6061
# Epoch 48 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1706, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 48 current val loss: 0.6060 best val loss: 0.6060 at epoch 48
# ----------
# epoch 49/1000
# 1/4, train_loss: 0.6052
# 2/4, train_loss: 0.6054
# 3/4, train_loss: 0.6063
# 4/4, train_loss: 0.6054
# epoch 49 average loss: 0.6056
# Epoch 49 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1742, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 49 current val loss: 0.6055 best val loss: 0.6055 at epoch 49
# ----------
# epoch 50/1000
# 1/4, train_loss: 0.6054
# 2/4, train_loss: 0.6049
# 3/4, train_loss: 0.6046
# 4/4, train_loss: 0.6051
# epoch 50 average loss: 0.6050
# Epoch 50 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1723, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 50 current val loss: 0.6050 best val loss: 0.6050 at epoch 50
# ----------
# epoch 51/1000
# 1/4, train_loss: 0.6054
# 2/4, train_loss: 0.6041
# 3/4, train_loss: 0.6046
# 4/4, train_loss: 0.6039
# epoch 51 average loss: 0.6045
# Epoch 51 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1722, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 51 current val loss: 0.6045 best val loss: 0.6045 at epoch 51
# ----------
# epoch 52/1000
# 1/4, train_loss: 0.6035
# 2/4, train_loss: 0.6037
# 3/4, train_loss: 0.6051
# 4/4, train_loss: 0.6036
# epoch 52 average loss: 0.6040
# Epoch 52 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1770, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 52 current val loss: 0.6040 best val loss: 0.6040 at epoch 52
# ----------
# epoch 53/1000
# 1/4, train_loss: 0.6033
# 2/4, train_loss: 0.6037
# 3/4, train_loss: 0.6033
# 4/4, train_loss: 0.6035
# epoch 53 average loss: 0.6035
# Epoch 53 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1785, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 53 current val loss: 0.6035 best val loss: 0.6035 at epoch 53
# ----------
# epoch 54/1000
# 1/4, train_loss: 0.6032
# 2/4, train_loss: 0.6024
# 3/4, train_loss: 0.6039
# 4/4, train_loss: 0.6024
# epoch 54 average loss: 0.6030
# Epoch 54 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1749, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 54 current val loss: 0.6031 best val loss: 0.6031 at epoch 54
# ----------
# epoch 55/1000
# 1/4, train_loss: 0.6034
# 2/4, train_loss: 0.6025
# 3/4, train_loss: 0.6019
# 4/4, train_loss: 0.6023
# epoch 55 average loss: 0.6025
# Epoch 55 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1750, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 55 current val loss: 0.6027 best val loss: 0.6027 at epoch 55
# ----------
# epoch 56/1000
# 1/4, train_loss: 0.6017
# 2/4, train_loss: 0.6024
# 3/4, train_loss: 0.6017
# 4/4, train_loss: 0.6026
# epoch 56 average loss: 0.6021
# Epoch 56 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1770, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 56 current val loss: 0.6022 best val loss: 0.6022 at epoch 56
# ----------
# epoch 57/1000
# 1/4, train_loss: 0.6016
# 2/4, train_loss: 0.6011
# 3/4, train_loss: 0.6028
# 4/4, train_loss: 0.6013
# epoch 57 average loss: 0.6017
# Epoch 57 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1804, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 57 current val loss: 0.6018 best val loss: 0.6018 at epoch 57
# ----------
# epoch 58/1000
# 1/4, train_loss: 0.6016
# 2/4, train_loss: 0.6012
# 3/4, train_loss: 0.6014
# 4/4, train_loss: 0.6011
# epoch 58 average loss: 0.6013
# Epoch 58 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1788, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 58 current val loss: 0.6016 best val loss: 0.6016 at epoch 58
# ----------
# epoch 59/1000
# 1/4, train_loss: 0.6008
# 2/4, train_loss: 0.6013
# 3/4, train_loss: 0.6012
# 4/4, train_loss: 0.6008
# epoch 59 average loss: 0.6010
# Epoch 59 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1813, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 59 current val loss: 0.6011 best val loss: 0.6011 at epoch 59
# ----------
# epoch 60/1000
# 1/4, train_loss: 0.6013
# 2/4, train_loss: 0.6003
# 3/4, train_loss: 0.6005
# 4/4, train_loss: 0.6002
# epoch 60 average loss: 0.6005
# Epoch 60 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1790, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 60 current val loss: 0.6007 best val loss: 0.6007 at epoch 60
# ----------
# epoch 61/1000
# 1/4, train_loss: 0.6012
# 2/4, train_loss: 0.6000
# 3/4, train_loss: 0.5999
# 4/4, train_loss: 0.5997
# epoch 61 average loss: 0.6002
# Epoch 61 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1785, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 61 current val loss: 0.6003 best val loss: 0.6003 at epoch 61
# ----------
# epoch 62/1000
# 1/4, train_loss: 0.6000
# 2/4, train_loss: 0.5993
# 3/4, train_loss: 0.6005
# 4/4, train_loss: 0.5996
# epoch 62 average loss: 0.5998
# Epoch 62 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1795, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 62 current val loss: 0.6001 best val loss: 0.6001 at epoch 62
# ----------
# epoch 63/1000
# 1/4, train_loss: 0.5991
# 2/4, train_loss: 0.5992
# 3/4, train_loss: 0.5998
# 4/4, train_loss: 0.5999
# epoch 63 average loss: 0.5995
# Epoch 63 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.1836, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 63 current val loss: 0.5997 best val loss: 0.5997 at epoch 63
# ----------
# epoch 64/1000
# 1/4, train_loss: 0.5987
# 2/4, train_loss: 0.5985
# 3/4, train_loss: 0.5997
# 4/4, train_loss: 0.5997
# epoch 64 average loss: 0.5991
# Epoch 64 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1842, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 64 current val loss: 0.5994 best val loss: 0.5994 at epoch 64
# ----------
# epoch 65/1000
# 1/4, train_loss: 0.5985
# 2/4, train_loss: 0.5990
# 3/4, train_loss: 0.5993
# 4/4, train_loss: 0.5985
# epoch 65 average loss: 0.5989
# Epoch 65 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1810, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 65 current val loss: 0.5991 best val loss: 0.5991 at epoch 65
# ----------
# epoch 66/1000
# 1/4, train_loss: 0.5987
# 2/4, train_loss: 0.5987
# 3/4, train_loss: 0.5985
# 4/4, train_loss: 0.5983
# epoch 66 average loss: 0.5985
# Epoch 66 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1802, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 66 current val loss: 0.5988 best val loss: 0.5988 at epoch 66
# ----------
# epoch 67/1000
# 1/4, train_loss: 0.5980
# 2/4, train_loss: 0.5992
# 3/4, train_loss: 0.5986
# 4/4, train_loss: 0.5973
# epoch 67 average loss: 0.5982
# Epoch 67 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1867, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 67 current val loss: 0.5986 best val loss: 0.5986 at epoch 67
# ----------
# epoch 68/1000
# 1/4, train_loss: 0.5983
# 2/4, train_loss: 0.5975
# 3/4, train_loss: 0.5980
# 4/4, train_loss: 0.5980
# epoch 68 average loss: 0.5980
# Epoch 68 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1826, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 68 current val loss: 0.5982 best val loss: 0.5982 at epoch 68
# ----------
# epoch 69/1000
# 1/4, train_loss: 0.5974
# 2/4, train_loss: 0.5976
# 3/4, train_loss: 0.5985
# 4/4, train_loss: 0.5971
# epoch 69 average loss: 0.5976
# Epoch 69 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1838, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 69 current val loss: 0.5979 best val loss: 0.5979 at epoch 69
# ----------
# epoch 70/1000
# 1/4, train_loss: 0.5971
# 2/4, train_loss: 0.5973
# 3/4, train_loss: 0.5974
# 4/4, train_loss: 0.5978
# epoch 70 average loss: 0.5974
# Epoch 70 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1831, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 70 current val loss: 0.5977 best val loss: 0.5977 at epoch 70
# ----------
# epoch 71/1000
# 1/4, train_loss: 0.5965
# 2/4, train_loss: 0.5978
# 3/4, train_loss: 0.5973
# 4/4, train_loss: 0.5968
# epoch 71 average loss: 0.5971
# Epoch 71 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1846, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 71 current val loss: 0.5974 best val loss: 0.5974 at epoch 71
# ----------
# epoch 72/1000
# 1/4, train_loss: 0.5969
# 2/4, train_loss: 0.5968
# 3/4, train_loss: 0.5968
# 4/4, train_loss: 0.5969
# epoch 72 average loss: 0.5969
# Epoch 72 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1871, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 72 current val loss: 0.5972 best val loss: 0.5972 at epoch 72
# ----------
# epoch 73/1000
# 1/4, train_loss: 0.5976
# 2/4, train_loss: 0.5964
# 3/4, train_loss: 0.5965
# 4/4, train_loss: 0.5959
# epoch 73 average loss: 0.5966
# Epoch 73 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1839, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 73 current val loss: 0.5969 best val loss: 0.5969 at epoch 73
# ----------
# epoch 74/1000
# 1/4, train_loss: 0.5960
# 2/4, train_loss: 0.5960
# 3/4, train_loss: 0.5969
# 4/4, train_loss: 0.5964
# epoch 74 average loss: 0.5963
# Epoch 74 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1890, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 74 current val loss: 0.5967 best val loss: 0.5967 at epoch 74
# ----------
# epoch 75/1000
# 1/4, train_loss: 0.5958
# 2/4, train_loss: 0.5957
# 3/4, train_loss: 0.5965
# 4/4, train_loss: 0.5964
# epoch 75 average loss: 0.5961
# Epoch 75 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1880, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 75 current val loss: 0.5965 best val loss: 0.5965 at epoch 75
# ----------
# epoch 76/1000
# 1/4, train_loss: 0.5959
# 2/4, train_loss: 0.5961
# 3/4, train_loss: 0.5958
# 4/4, train_loss: 0.5958
# epoch 76 average loss: 0.5959
# Epoch 76 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1844, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 76 current val loss: 0.5962 best val loss: 0.5962 at epoch 76
# ----------
# epoch 77/1000
# 1/4, train_loss: 0.5959
# 2/4, train_loss: 0.5957
# 3/4, train_loss: 0.5955
# 4/4, train_loss: 0.5956
# epoch 77 average loss: 0.5957
# Epoch 77 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1869, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 77 current val loss: 0.5961 best val loss: 0.5961 at epoch 77
# ----------
# epoch 78/1000
# 1/4, train_loss: 0.5962
# 2/4, train_loss: 0.5948
# 3/4, train_loss: 0.5955
# 4/4, train_loss: 0.5954
# epoch 78 average loss: 0.5955
# Epoch 78 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1904, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 78 current val loss: 0.5957 best val loss: 0.5957 at epoch 78
# ----------
# epoch 79/1000
# 1/4, train_loss: 0.5954
# 2/4, train_loss: 0.5950
# 3/4, train_loss: 0.5953
# 4/4, train_loss: 0.5954
# epoch 79 average loss: 0.5952
# Epoch 79 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1849, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 79 current val loss: 0.5957 best val loss: 0.5957 at epoch 79
# ----------
# epoch 80/1000
# 1/4, train_loss: 0.5958
# 2/4, train_loss: 0.5947
# 3/4, train_loss: 0.5944
# 4/4, train_loss: 0.5953
# epoch 80 average loss: 0.5951
# Epoch 80 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1896, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 80 current val loss: 0.5955 best val loss: 0.5955 at epoch 80
# ----------
# epoch 81/1000
# 1/4, train_loss: 0.5949
# 2/4, train_loss: 0.5955
# 3/4, train_loss: 0.5943
# 4/4, train_loss: 0.5945
# epoch 81 average loss: 0.5948
# Epoch 81 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1862, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 81 current val loss: 0.5952 best val loss: 0.5952 at epoch 81
# ----------
# epoch 82/1000
# 1/4, train_loss: 0.5949
# 2/4, train_loss: 0.5945
# 3/4, train_loss: 0.5939
# 4/4, train_loss: 0.5951
# epoch 82 average loss: 0.5946
# Epoch 82 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1922, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 82 current val loss: 0.5949 best val loss: 0.5949 at epoch 82
# ----------
# epoch 83/1000
# 1/4, train_loss: 0.5939
# 2/4, train_loss: 0.5947
# 3/4, train_loss: 0.5940
# 4/4, train_loss: 0.5945
# epoch 83 average loss: 0.5943
# Epoch 83 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1924, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 83 current val loss: 0.5947 best val loss: 0.5947 at epoch 83
# ----------
# epoch 84/1000
# 1/4, train_loss: 0.5936
# 2/4, train_loss: 0.5946
# 3/4, train_loss: 0.5939
# 4/4, train_loss: 0.5943
# epoch 84 average loss: 0.5941
# Epoch 84 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1899, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 84 current val loss: 0.5945 best val loss: 0.5945 at epoch 84
# ----------
# epoch 85/1000
# 1/4, train_loss: 0.5937
# 2/4, train_loss: 0.5941
# 3/4, train_loss: 0.5940
# 4/4, train_loss: 0.5937
# epoch 85 average loss: 0.5939
# Epoch 85 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1890, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 85 current val loss: 0.5942 best val loss: 0.5942 at epoch 85
# ----------
# epoch 86/1000
# 1/4, train_loss: 0.5934
# 2/4, train_loss: 0.5935
# 3/4, train_loss: 0.5941
# 4/4, train_loss: 0.5937
# epoch 86 average loss: 0.5936
# Epoch 86 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1936, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 86 current val loss: 0.5940 best val loss: 0.5940 at epoch 86
# ----------
# epoch 87/1000
# 1/4, train_loss: 0.5934
# 2/4, train_loss: 0.5935
# 3/4, train_loss: 0.5936
# 4/4, train_loss: 0.5933
# epoch 87 average loss: 0.5935
# Epoch 87 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1889, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 87 current val loss: 0.5939 best val loss: 0.5939 at epoch 87
# ----------
# epoch 88/1000
# 1/4, train_loss: 0.5932
# 2/4, train_loss: 0.5935
# 3/4, train_loss: 0.5934
# 4/4, train_loss: 0.5930
# epoch 88 average loss: 0.5933
# Epoch 88 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1907, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 88 current val loss: 0.5937 best val loss: 0.5937 at epoch 88
# ----------
# epoch 89/1000
# 1/4, train_loss: 0.5932
# 2/4, train_loss: 0.5932
# 3/4, train_loss: 0.5932
# 4/4, train_loss: 0.5927
# epoch 89 average loss: 0.5931
# Epoch 89 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1913, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 89 current val loss: 0.5935 best val loss: 0.5935 at epoch 89
# ----------
# epoch 90/1000
# 1/4, train_loss: 0.5928
# 2/4, train_loss: 0.5932
# 3/4, train_loss: 0.5927
# 4/4, train_loss: 0.5929
# epoch 90 average loss: 0.5929
# Epoch 90 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1907, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 90 current val loss: 0.5933 best val loss: 0.5933 at epoch 90
# ----------
# epoch 91/1000
# 1/4, train_loss: 0.5924
# 2/4, train_loss: 0.5935
# 3/4, train_loss: 0.5926
# 4/4, train_loss: 0.5923
# epoch 91 average loss: 0.5927
# Epoch 91 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1940, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 91 current val loss: 0.5930 best val loss: 0.5930 at epoch 91
# ----------
# epoch 92/1000
# 1/4, train_loss: 0.5923
# 2/4, train_loss: 0.5924
# 3/4, train_loss: 0.5927
# 4/4, train_loss: 0.5925
# epoch 92 average loss: 0.5925
# Epoch 92 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1956, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 92 current val loss: 0.5929 best val loss: 0.5929 at epoch 92
# ----------
# epoch 93/1000
# 1/4, train_loss: 0.5927
# 2/4, train_loss: 0.5920
# 3/4, train_loss: 0.5926
# 4/4, train_loss: 0.5919
# epoch 93 average loss: 0.5923
# Epoch 93 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1909, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 93 current val loss: 0.5928 best val loss: 0.5928 at epoch 93
# ----------
# epoch 94/1000
# 1/4, train_loss: 0.5927
# 2/4, train_loss: 0.5922
# 3/4, train_loss: 0.5919
# 4/4, train_loss: 0.5918
# epoch 94 average loss: 0.5922
# Epoch 94 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1956, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 94 current val loss: 0.5925 best val loss: 0.5925 at epoch 94
# ----------
# epoch 95/1000
# 1/4, train_loss: 0.5925
# 2/4, train_loss: 0.5920
# 3/4, train_loss: 0.5921
# 4/4, train_loss: 0.5911
# epoch 95 average loss: 0.5920
# Epoch 95 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1939, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 95 current val loss: 0.5923 best val loss: 0.5923 at epoch 95
# ----------
# epoch 96/1000
# 1/4, train_loss: 0.5917
# 2/4, train_loss: 0.5922
# 3/4, train_loss: 0.5918
# 4/4, train_loss: 0.5915
# epoch 96 average loss: 0.5918
# Epoch 96 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1972, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 96 current val loss: 0.5921 best val loss: 0.5921 at epoch 96
# ----------
# epoch 97/1000
# 1/4, train_loss: 0.5912
# 2/4, train_loss: 0.5921
# 3/4, train_loss: 0.5909
# 4/4, train_loss: 0.5920
# epoch 97 average loss: 0.5916
# Epoch 97 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1985, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 97 current val loss: 0.5919 best val loss: 0.5919 at epoch 97
# ----------
# epoch 98/1000
# 1/4, train_loss: 0.5917
# 2/4, train_loss: 0.5912
# 3/4, train_loss: 0.5909
# 4/4, train_loss: 0.5917
# epoch 98 average loss: 0.5914
# Epoch 98 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1943, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 98 current val loss: 0.5918 best val loss: 0.5918 at epoch 98
# ----------
# epoch 99/1000
# 1/4, train_loss: 0.5916
# 2/4, train_loss: 0.5912
# 3/4, train_loss: 0.5909
# 4/4, train_loss: 0.5910
# epoch 99 average loss: 0.5912
# Epoch 99 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1962, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 99 current val loss: 0.5916 best val loss: 0.5916 at epoch 99
# ----------
# epoch 100/1000
# 1/4, train_loss: 0.5915
# 2/4, train_loss: 0.5907
# 3/4, train_loss: 0.5915
# 4/4, train_loss: 0.5904
# epoch 100 average loss: 0.5910
# Epoch 100 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1956, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 100 current val loss: 0.5914 best val loss: 0.5914 at epoch 100
# ----------
# epoch 101/1000
# 1/4, train_loss: 0.5906
# 2/4, train_loss: 0.5912
# 3/4, train_loss: 0.5911
# 4/4, train_loss: 0.5907
# epoch 101 average loss: 0.5909
# Epoch 101 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1952, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 101 current val loss: 0.5912 best val loss: 0.5912 at epoch 101
# ----------
# epoch 102/1000
# 1/4, train_loss: 0.5907
# 2/4, train_loss: 0.5903
# 3/4, train_loss: 0.5906
# 4/4, train_loss: 0.5912
# epoch 102 average loss: 0.5907
# Epoch 102 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1956, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 102 current val loss: 0.5911 best val loss: 0.5911 at epoch 102
# ----------
# epoch 103/1000
# 1/4, train_loss: 0.5906
# 2/4, train_loss: 0.5908
# 3/4, train_loss: 0.5902
# 4/4, train_loss: 0.5905
# epoch 103 average loss: 0.5905
# Epoch 103 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1991, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 103 current val loss: 0.5909 best val loss: 0.5909 at epoch 103
# ----------
# epoch 104/1000
# 1/4, train_loss: 0.5902
# 2/4, train_loss: 0.5903
# 3/4, train_loss: 0.5906
# 4/4, train_loss: 0.5904
# epoch 104 average loss: 0.5904
# Epoch 104 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1962, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 104 current val loss: 0.5907 best val loss: 0.5907 at epoch 104
# ----------
# epoch 105/1000
# 1/4, train_loss: 0.5908
# 2/4, train_loss: 0.5897
# 3/4, train_loss: 0.5903
# 4/4, train_loss: 0.5900
# epoch 105 average loss: 0.5902
# Epoch 105 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1987, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 105 current val loss: 0.5906 best val loss: 0.5906 at epoch 105
# ----------
# epoch 106/1000
# 1/4, train_loss: 0.5898
# 2/4, train_loss: 0.5899
# 3/4, train_loss: 0.5901
# 4/4, train_loss: 0.5904
# epoch 106 average loss: 0.5900
# Epoch 106 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2014, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 106 current val loss: 0.5904 best val loss: 0.5904 at epoch 106
# ----------
# epoch 107/1000
# 1/4, train_loss: 0.5900
# 2/4, train_loss: 0.5894
# 3/4, train_loss: 0.5900
# 4/4, train_loss: 0.5900
# epoch 107 average loss: 0.5899
# Epoch 107 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.1998, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 107 current val loss: 0.5903 best val loss: 0.5903 at epoch 107
# ----------
# epoch 108/1000
# 1/4, train_loss: 0.5904
# 2/4, train_loss: 0.5899
# 3/4, train_loss: 0.5893
# 4/4, train_loss: 0.5893
# epoch 108 average loss: 0.5897
# Epoch 108 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2020, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 108 current val loss: 0.5901 best val loss: 0.5901 at epoch 108
# ----------
# epoch 109/1000
# 1/4, train_loss: 0.5894
# 2/4, train_loss: 0.5891
# 3/4, train_loss: 0.5900
# 4/4, train_loss: 0.5897
# epoch 109 average loss: 0.5896
# Epoch 109 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2017, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 109 current val loss: 0.5900 best val loss: 0.5900 at epoch 109
# ----------
# epoch 110/1000
# 1/4, train_loss: 0.5901
# 2/4, train_loss: 0.5894
# 3/4, train_loss: 0.5890
# 4/4, train_loss: 0.5893
# epoch 110 average loss: 0.5894
# Epoch 110 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2014, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 110 current val loss: 0.5898 best val loss: 0.5898 at epoch 110
# ----------
# epoch 111/1000
# 1/4, train_loss: 0.5893
# 2/4, train_loss: 0.5893
# 3/4, train_loss: 0.5889
# 4/4, train_loss: 0.5897
# epoch 111 average loss: 0.5893
# Epoch 111 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.2034, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 111 current val loss: 0.5896 best val loss: 0.5896 at epoch 111
# ----------
# epoch 112/1000
# 1/4, train_loss: 0.5891
# 2/4, train_loss: 0.5891
# 3/4, train_loss: 0.5891
# 4/4, train_loss: 0.5892
# epoch 112 average loss: 0.5891
# Epoch 112 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.1986, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 112 current val loss: 0.5895 best val loss: 0.5895 at epoch 112
# ----------
# epoch 113/1000
# 1/4, train_loss: 0.5885
# 2/4, train_loss: 0.5891
# 3/4, train_loss: 0.5892
# 4/4, train_loss: 0.5892
# epoch 113 average loss: 0.5890
# Epoch 113 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.2034, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 113 current val loss: 0.5894 best val loss: 0.5894 at epoch 113
# ----------
# epoch 114/1000
# 1/4, train_loss: 0.5890
# 2/4, train_loss: 0.5890
# 3/4, train_loss: 0.5886
# 4/4, train_loss: 0.5888
# epoch 114 average loss: 0.5888
# Epoch 114 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2028, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 114 current val loss: 0.5892 best val loss: 0.5892 at epoch 114
# ----------
# epoch 115/1000
# 1/4, train_loss: 0.5892
# 2/4, train_loss: 0.5889
# 3/4, train_loss: 0.5884
# 4/4, train_loss: 0.5884
# epoch 115 average loss: 0.5887
# Epoch 115 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2000, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 115 current val loss: 0.5891 best val loss: 0.5891 at epoch 115
# ----------
# epoch 116/1000
# 1/4, train_loss: 0.5883
# 2/4, train_loss: 0.5886
# 3/4, train_loss: 0.5883
# 4/4, train_loss: 0.5889
# epoch 116 average loss: 0.5885
# Epoch 116 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2001, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 116 current val loss: 0.5889 best val loss: 0.5889 at epoch 116
# ----------
# epoch 117/1000
# 1/4, train_loss: 0.5888
# 2/4, train_loss: 0.5883
# 3/4, train_loss: 0.5883
# 4/4, train_loss: 0.5882
# epoch 117 average loss: 0.5884
# Epoch 117 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.2018, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 117 current val loss: 0.5888 best val loss: 0.5888 at epoch 117
# ----------
# epoch 118/1000
# 1/4, train_loss: 0.5886
# 2/4, train_loss: 0.5879
# 3/4, train_loss: 0.5885
# 4/4, train_loss: 0.5881
# epoch 118 average loss: 0.5883
# Epoch 118 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2038, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 118 current val loss: 0.5886 best val loss: 0.5886 at epoch 118
# ----------
# epoch 119/1000
# 1/4, train_loss: 0.5878
# 2/4, train_loss: 0.5888
# 3/4, train_loss: 0.5877
# 4/4, train_loss: 0.5881
# epoch 119 average loss: 0.5881
# Epoch 119 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.2015, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 119 current val loss: 0.5885 best val loss: 0.5885 at epoch 119
# ----------
# epoch 120/1000
# 1/4, train_loss: 0.5877
# 2/4, train_loss: 0.5877
# 3/4, train_loss: 0.5884
# 4/4, train_loss: 0.5881
# epoch 120 average loss: 0.5880
# Epoch 120 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.2059, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 120 current val loss: 0.5883 best val loss: 0.5883 at epoch 120
# ----------
# epoch 121/1000
# 1/4, train_loss: 0.5881
# 2/4, train_loss: 0.5880
# 3/4, train_loss: 0.5875
# 4/4, train_loss: 0.5876
# epoch 121 average loss: 0.5878
# Epoch 121 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.2071, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 121 current val loss: 0.5882 best val loss: 0.5882 at epoch 121
# ----------
# epoch 122/1000
# 1/4, train_loss: 0.5879
# 2/4, train_loss: 0.5876
# 3/4, train_loss: 0.5873
# 4/4, train_loss: 0.5879
# epoch 122 average loss: 0.5877
# Epoch 122 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2075, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 122 current val loss: 0.5880 best val loss: 0.5880 at epoch 122
# ----------
# epoch 123/1000
# 1/4, train_loss: 0.5878
# 2/4, train_loss: 0.5873
# 3/4, train_loss: 0.5877
# 4/4, train_loss: 0.5873
# epoch 123 average loss: 0.5875
# Epoch 123 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2074, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 123 current val loss: 0.5879 best val loss: 0.5879 at epoch 123
# ----------
# epoch 124/1000
# 1/4, train_loss: 0.5875
# 2/4, train_loss: 0.5872
# 3/4, train_loss: 0.5876
# 4/4, train_loss: 0.5873
# epoch 124 average loss: 0.5874
# Epoch 124 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.2037, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 124 current val loss: 0.5877 best val loss: 0.5877 at epoch 124
# ----------
# epoch 125/1000
# 1/4, train_loss: 0.5873
# 2/4, train_loss: 0.5872
# 3/4, train_loss: 0.5871
# 4/4, train_loss: 0.5873
# epoch 125 average loss: 0.5872
# Epoch 125 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2063, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 125 current val loss: 0.5876 best val loss: 0.5876 at epoch 125
# ----------
# epoch 126/1000
# 1/4, train_loss: 0.5870
# 2/4, train_loss: 0.5870
# 3/4, train_loss: 0.5869
# 4/4, train_loss: 0.5876
# epoch 126 average loss: 0.5871
# Epoch 126 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.2088, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 126 current val loss: 0.5875 best val loss: 0.5875 at epoch 126
# ----------
# epoch 127/1000
# 1/4, train_loss: 0.5870
# 2/4, train_loss: 0.5871
# 3/4, train_loss: 0.5869
# 4/4, train_loss: 0.5869
# epoch 127 average loss: 0.5870
# Epoch 127 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2094, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 127 current val loss: 0.5873 best val loss: 0.5873 at epoch 127
# ----------
# epoch 128/1000
# 1/4, train_loss: 0.5867
# 2/4, train_loss: 0.5869
# 3/4, train_loss: 0.5867
# 4/4, train_loss: 0.5869
# epoch 128 average loss: 0.5868
# Epoch 128 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2072, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 128 current val loss: 0.5871 best val loss: 0.5871 at epoch 128
# ----------
# epoch 129/1000
# 1/4, train_loss: 0.5863
# 2/4, train_loss: 0.5868
# 3/4, train_loss: 0.5870
# 4/4, train_loss: 0.5867
# epoch 129 average loss: 0.5867
# Epoch 129 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.2097, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 129 current val loss: 0.5870 best val loss: 0.5870 at epoch 129
# ----------
# epoch 130/1000
# 1/4, train_loss: 0.5867
# 2/4, train_loss: 0.5868
# 3/4, train_loss: 0.5864
# 4/4, train_loss: 0.5863
# epoch 130 average loss: 0.5865
# Epoch 130 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2085, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 130 current val loss: 0.5869 best val loss: 0.5869 at epoch 130
# ----------
# epoch 131/1000
# 1/4, train_loss: 0.5861
# 2/4, train_loss: 0.5864
# 3/4, train_loss: 0.5865
# 4/4, train_loss: 0.5867
# epoch 131 average loss: 0.5864
# Epoch 131 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2059, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 131 current val loss: 0.5867 best val loss: 0.5867 at epoch 131
# ----------
# epoch 132/1000
# 1/4, train_loss: 0.5864
# 2/4, train_loss: 0.5862
# 3/4, train_loss: 0.5863
# 4/4, train_loss: 0.5862
# epoch 132 average loss: 0.5863
# Epoch 132 - Dice Score: 0.0005, Precision: 0.0003, Recall: -0.2070, F1-Score: 0.0005, IoU: 0.0003
# saved new best metric model
# current epoch: 132 current val loss: 0.5866 best val loss: 0.5866 at epoch 132
# ----------
# epoch 133/1000
# 1/4, train_loss: 0.5864
# 2/4, train_loss: 0.5862
# 3/4, train_loss: 0.5857
# 4/4, train_loss: 0.5863
# epoch 133 average loss: 0.5862
# Epoch 133 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2096, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 133 current val loss: 0.5865 best val loss: 0.5865 at epoch 133
# ----------
# epoch 134/1000
# 1/4, train_loss: 0.5863
# 2/4, train_loss: 0.5860
# 3/4, train_loss: 0.5859
# 4/4, train_loss: 0.5859
# epoch 134 average loss: 0.5860
# Epoch 134 - Dice Score: 0.0007, Precision: 0.0003, Recall: -0.2119, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 134 current val loss: 0.5863 best val loss: 0.5863 at epoch 134
# ----------
# epoch 135/1000
# 1/4, train_loss: 0.5859
# 2/4, train_loss: 0.5859
# 3/4, train_loss: 0.5861
# 4/4, train_loss: 0.5857
# epoch 135 average loss: 0.5859
# Epoch 135 - Dice Score: 0.0006, Precision: 0.0003, Recall: -0.2119, F1-Score: 0.0006, IoU: 0.0003
# saved new best metric model
# current epoch: 135 current val loss: 0.5862 best val loss: 0.5862 at epoch 135

# %%
# Visualizar imagem, rótulo e saída para o primeiro exemplo no lote
f, axarr = plt.subplots(1, 3)

# Imagem original
img = val_images[0].detach().cpu().permute(1, 2, 0)
axarr[0].imshow(img)

# Rótulo (Ground Truth)
label = val_labels[0].detach().cpu()
axarr[1].imshow(label, cmap='gray')

# Saída do Modelo (Previsão)
output = torch.sigmoid(val_outputs[0]).detach().cpu() 
axarr[2].imshow(output, cmap='gray')
axarr[2].set_title('Saída do Modelo')

plt.show()
